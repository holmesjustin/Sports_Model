# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling

import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
outcomePath = '/Users/justinholmes/Desktop/Sports_Model/Data/outcomeData.csv'
featurePath = '/Users/justinholmes/Desktop/Sports_Model/Data/feature_data_normal.csv'

# %%
outcomeData = pd.read_csv(outcomePath)
featureData = pd.read_csv(featurePath)

# %% [markdown]
# ### Format all data

# %%
# drop unwanted columns
outcomeData = outcomeData.drop(["Start Time", "Box Score", "Notes"], axis=1)

# %%
# change OT to integer value for number of OT rounds
outcomeData.loc[(outcomeData["OT?"].isna()),'OT?']= 0
outcomeData.loc[(outcomeData["OT?"] == "OT"),'OT?']= 1
outcomeData.loc[(outcomeData["OT?"] == "2OT"),'OT?']= 2
outcomeData.loc[(outcomeData["OT?"] == "3OT"),'OT?']= 3
outcomeData.loc[(outcomeData["OT?"] == "4OT"),'OT?']= 4

# %%
def redefineTeamNames(dataframe):
    dataframe = dataframe.replace('Seattle SuperSonics', 'Oklahoma City Thunder', regex=True)
    
    dataframe = dataframe.replace('New Orleans/Oklahoma City Hornets', 'New Orleans Pelicans', regex=True)

    dataframe = dataframe.replace('New Orleans Hornets', 'New Orleans Pelicans', regex=True)
    
    dataframe = dataframe.replace('Charlotte Bobcats', 'Charlotte Hornets', regex=True)
    
    dataframe = dataframe.replace('New Jersey Nets', 'Brooklyn Nets', regex=True)
    
    return dataframe

outcomeData = redefineTeamNames(outcomeData)

# %%
# outcomeData["Final Home Spread"] = (outcomeData["VisitorPTS"] - outcomeData["HomePTS"]).astype(float)

# %%
outcomeData = pd.concat([outcomeData, featureData], axis=1, sort=False)

# %%
def homeWin(dataframe):
    if dataframe['Winner'] == dataframe['Home']:
        return True
    else:
        return False

outcomeData['HomeWin'] = outcomeData.apply(homeWin, axis=1)

# %%
outcomeData.head()
# Out:
#    Year     Month           Visitor  VisitorPTS                 Home  HomePTS  \
# 0  2005  november   Houston Rockets          79      Detroit Pistons       87
# 1  2005  november  Sacramento Kings          98     Dallas Mavericks      107
# 2  2005  november    Denver Nuggets          78   Los Angeles Lakers       89
# 3  2005  november    Indiana Pacers         109  Cleveland Cavaliers      104
# 4  2005  november   Milwaukee Bucks          92        Orlando Magic       93
#
#    OT?  Attend  Total Points              Winner  ...  TRB_PG_visitor  \
# 0    0   22076           166     Detroit Pistons  ...            42.4
# 1    0   20041           205    Dallas Mavericks  ...            42.4
# 2    0   18997           167  Los Angeles Lakers  ...            42.0
# 3    2   19730           213      Indiana Pacers  ...            40.1
# 4    0   15138           185       Orlando Magic  ...            41.3
#
#    AST_PG_home  AST_PG_visitor  STL_PG_home  STL_PG_visitor  BLK_PG_home  \
# 0         21.8            21.1          7.0             6.9          6.1
# 1         19.6            24.5          8.6             8.2          5.6
# 2         20.4            23.9          6.2             9.1          4.2
# 3         22.6            18.2          8.0             7.5          5.6
# 4         19.3            21.0          7.7             6.5          5.4
#
#    BLK_PG_visitor  TOV_PG_home  TOV_PG_visitor  HomeWin
# 0             4.6         13.8            13.8     True
# 1             3.9         13.4            13.1     True
# 2             6.0         14.3            14.9     True
# 3             4.4         13.9            14.3    False
# 4             3.5         16.1            13.8     True
#
# [5 rows x 39 columns]

# %%
encoding = LabelEncoder()
encoding.fit(outcomeData['Home'].values)
outcomeData['Home'] = encoding.transform(outcomeData['Home'].values)
outcomeData['Visitor'] = encoding.transform(outcomeData['Visitor'].values)

# %%
outcomeData = outcomeData.drop(['Month', 'Attend', 'Winner', 'VisitorPTS', 'HomePTS', 'Total Points'
                                ], axis=1)

# %%
outcomeData.head()
# Out:
#    Year  Visitor  Home  OT?  FGA_PG_home  FGA_PG_visitor  FG%_PG_home  \
# 0  2005       10     8    0         78.3            78.3         44.4
# 1  2005       25     6    0         81.6            85.1         45.7
# 2  2005        7    13    0         80.8            80.7         43.7
# 3  2005       11     5    2         81.5            75.2         44.7
# 4  2005       16    21    0         81.5            80.2         45.4
#
#    FG%_PG_visitor  3P_PG_home  3P_PG_visitor  ...  TRB_PG_visitor  \
# 0            44.3         4.4            6.7  ...            42.4
# 1            45.9         5.6            6.4  ...            42.4
# 2            45.9         7.9            3.9  ...            42.0
# 3            43.2         3.7            6.6  ...            40.1
# 4            45.0         3.9            4.0  ...            41.3
#
#    AST_PG_home  AST_PG_visitor  STL_PG_home  STL_PG_visitor  BLK_PG_home  \
# 0         21.8            21.1          7.0             6.9          6.1
# 1         19.6            24.5          8.6             8.2          5.6
# 2         20.4            23.9          6.2             9.1          4.2
# 3         22.6            18.2          8.0             7.5          5.6
# 4         19.3            21.0          7.7             6.5          5.4
#
#    BLK_PG_visitor  TOV_PG_home  TOV_PG_visitor  HomeWin
# 0             4.6         13.8            13.8     True
# 1             3.9         13.4            13.1     True
# 2             6.0         14.3            14.9     True
# 3             4.4         13.9            14.3    False
# 4             3.5         16.1            13.8     True
#
# [5 rows x 33 columns]

# %%
trainData = outcomeData.loc[outcomeData['Year'] < 2020]
testData = outcomeData.loc[outcomeData['Year'] == 2020]

# %%
trainData.head()
# Out:
#    Year  Visitor  Home  OT?  FGA_PG_home  FGA_PG_visitor  FG%_PG_home  \
# 0  2005       10     8    0         78.3            78.3         44.4
# 1  2005       25     6    0         81.6            85.1         45.7
# 2  2005        7    13    0         80.8            80.7         43.7
# 3  2005       11     5    2         81.5            75.2         44.7
# 4  2005       16    21    0         81.5            80.2         45.4
#
#    FG%_PG_visitor  3P_PG_home  3P_PG_visitor  ...  TRB_PG_visitor  \
# 0            44.3         4.4            6.7  ...            42.4
# 1            45.9         5.6            6.4  ...            42.4
# 2            45.9         7.9            3.9  ...            42.0
# 3            43.2         3.7            6.6  ...            40.1
# 4            45.0         3.9            4.0  ...            41.3
#
#    AST_PG_home  AST_PG_visitor  STL_PG_home  STL_PG_visitor  BLK_PG_home  \
# 0         21.8            21.1          7.0             6.9          6.1
# 1         19.6            24.5          8.6             8.2          5.6
# 2         20.4            23.9          6.2             9.1          4.2
# 3         22.6            18.2          8.0             7.5          5.6
# 4         19.3            21.0          7.7             6.5          5.4
#
#    BLK_PG_visitor  TOV_PG_home  TOV_PG_visitor  HomeWin
# 0             4.6         13.8            13.8     True
# 1             3.9         13.4            13.1     True
# 2             6.0         14.3            14.9     True
# 3             4.4         13.9            14.3    False
# 4             3.5         16.1            13.8     True
#
# [5 rows x 33 columns]

# %%
train_stats = trainData.drop(["Year", "Visitor", "Home", "OT?", "HomeWin"],axis=1).describe()

# %%
# train_stats = trainData.drop(["Final Home Spread"],axis=1).describe()

# %%
train_stats.head()
# Out:
#         FGA_PG_home  FGA_PG_visitor   FG%_PG_home  FG%_PG_visitor  \
# count  19463.000000    19463.000000  19463.000000    19463.000000
# mean      82.620341       82.622401     45.605739       45.601654
# std        3.556795        3.555530      1.524318        1.521335
# min       74.300000       74.300000     40.800000       40.800000
# 25%       80.100000       80.200000     44.500000       44.500000
#
#          3P_PG_home  3P_PG_visitor   3PA_PG_home  3PA_PG_visitor  \
# count  19463.000000   19463.000000  19463.000000    19463.000000
# mean       7.564841       7.560587     21.133443       21.125407
# std        2.286268       2.282431      6.127855        6.119273
# min        2.800000       2.800000      8.200000        8.200000
# 25%        6.000000       6.000000     17.000000       17.000000
#
#         3P%_PG_home  3P%_PG_visitor  ...   TRB_PG_home  TRB_PG_visitor  \
# count  19463.000000    19463.000000  ...  19463.000000    19463.000000
# mean      35.679654       35.673611  ...     42.469003       42.467847
# std        1.852468        1.848079  ...      2.034234        2.034172
# min       29.500000       29.500000  ...     36.900000       36.900000
# 25%       34.500000       34.500000  ...     41.000000       41.000000
#
#         AST_PG_home  AST_PG_visitor   STL_PG_home  STL_PG_visitor  \
# count  19463.000000    19463.000000  19463.000000    19463.000000
# mean      21.956523       21.953702      7.526085        7.525608
# std        2.073438        2.068351      0.848075        0.848417
# min       17.400000       17.400000      5.500000        5.500000
# 25%       20.500000       20.500000      7.000000        7.000000
#
#         BLK_PG_home  BLK_PG_visitor   TOV_PG_home  TOV_PG_visitor
# count  19463.000000    19463.000000  19463.000000    19463.000000
# mean       4.856045        4.854426     14.348307       14.348281
# std        0.787876        0.787309      1.103789        1.103771
# min        2.400000        2.400000     11.200000       11.200000
# 25%        4.300000        4.300000     13.700000       13.700000
#
# [5 rows x 28 columns]

# %%
train_stats = train_stats.transpose()
train_stats
# Out:
#                   count       mean       std   min   25%   50%   75%   max
# FGA_PG_home     19463.0  82.620341  3.556795  74.3  80.1  82.4  85.2  94.0
# FGA_PG_visitor  19463.0  82.622401  3.555530  74.3  80.2  82.4  85.2  94.0
# FG%_PG_home     19463.0  45.605739  1.524318  40.8  44.5  45.5  46.5  50.4
# FG%_PG_visitor  19463.0  45.601654  1.521335  40.8  44.5  45.5  46.5  50.4
# 3P_PG_home      19463.0   7.564841  2.286268   2.8   6.0   7.2   9.0  16.1
# 3P_PG_visitor   19463.0   7.560587  2.282431   2.8   6.0   7.2   9.0  16.1
# 3PA_PG_home     19463.0  21.133443  6.127855   8.2  17.0  19.9  25.1  45.4
# 3PA_PG_visitor  19463.0  21.125407  6.119273   8.2  17.0  19.9  25.1  45.4
# 3P%_PG_home     19463.0  35.679654  1.852468  29.5  34.5  35.6  37.0  41.6
# 3P%_PG_visitor  19463.0  35.673611  1.848079  29.5  34.5  35.6  36.9  41.6
# 2P_PG_home      19463.0  30.115537  1.898498  23.1  29.0  30.2  31.4  35.3
# 2P_PG_visitor   19463.0  30.117413  1.897855  23.1  29.0  30.2  31.4  35.3
# 2PA_PG_home     19463.0  61.485922  4.594168  41.9  58.6  62.0  64.5  74.3
# 2PA_PG_visitor  19463.0  61.495992  4.587346  41.9  58.6  62.0  64.5  74.3
# ORB_PG_home     19463.0  10.868335  1.240189   7.6  10.0  10.9  11.8  14.6
# ORB_PG_visitor  19463.0  10.869424  1.240431   7.6  10.0  10.9  11.8  14.6
# DRB_PG_home     19463.0  31.603206  2.111577  26.9  30.0  31.5  33.1  40.4
# DRB_PG_visitor  19463.0  31.600961  2.110058  26.9  30.0  31.5  33.1  40.4
# TRB_PG_home     19463.0  42.469003  2.034234  36.9  41.0  42.3  43.8  49.7
# TRB_PG_visitor  19463.0  42.467847  2.034172  36.9  41.0  42.3  43.8  49.7
# AST_PG_home     19463.0  21.956523  2.073438  17.4  20.5  21.7  23.2  30.4
# AST_PG_visitor  19463.0  21.953702  2.068351  17.4  20.5  21.7  23.2  30.4
# STL_PG_home     19463.0   7.526085  0.848075   5.5   7.0   7.5   8.1  10.0
# STL_PG_visitor  19463.0   7.525608  0.848417   5.5   7.0   7.5   8.1  10.0
# BLK_PG_home     19463.0   4.856045  0.787876   2.4   4.3   4.8   5.4   8.2
# BLK_PG_visitor  19463.0   4.854426  0.787309   2.4   4.3   4.8   5.4   8.2
# TOV_PG_home     19463.0  14.348307  1.103789  11.2  13.7  14.3  15.0  17.7
# TOV_PG_visitor  19463.0  14.348281  1.103771  11.2  13.7  14.3  15.0  17.7

# %%
train_labels = trainData.pop('HomeWin')
test_labels = testData.pop('HomeWin')

# %%
def norm(x):
  return (x - train_stats['mean']) / train_stats['std']

# %%
trainData.head()
# Out:
#    Year  Visitor  Home  OT?  FGA_PG_home  FGA_PG_visitor  FG%_PG_home  \
# 0  2005       10     8    0         78.3            78.3         44.4
# 1  2005       25     6    0         81.6            85.1         45.7
# 2  2005        7    13    0         80.8            80.7         43.7
# 3  2005       11     5    2         81.5            75.2         44.7
# 4  2005       16    21    0         81.5            80.2         45.4
#
#    FG%_PG_visitor  3P_PG_home  3P_PG_visitor  ...  TRB_PG_home  \
# 0            44.3         4.4            6.7  ...         43.4
# 1            45.9         5.6            6.4  ...         42.9
# 2            45.9         7.9            3.9  ...         43.2
# 3            43.2         3.7            6.6  ...         42.3
# 4            45.0         3.9            4.0  ...         43.7
#
#    TRB_PG_visitor  AST_PG_home  AST_PG_visitor  STL_PG_home  STL_PG_visitor  \
# 0            42.4         21.8            21.1          7.0             6.9
# 1            42.4         19.6            24.5          8.6             8.2
# 2            42.0         20.4            23.9          6.2             9.1
# 3            40.1         22.6            18.2          8.0             7.5
# 4            41.3         19.3            21.0          7.7             6.5
#
#    BLK_PG_home  BLK_PG_visitor  TOV_PG_home  TOV_PG_visitor
# 0          6.1             4.6         13.8            13.8
# 1          5.6             3.9         13.4            13.1
# 2          4.2             6.0         14.3            14.9
# 3          5.6             4.4         13.9            14.3
# 4          5.4             3.5         16.1            13.8
#
# [5 rows x 32 columns]

# %%
# regular_train_data = trainData[["Year", "Visitor", "Home", "OT?"]]
normed_train_data = norm(trainData.drop(["Year", "Visitor", "Home", "OT?"],axis=1))
# normed_train_data = pd.concat([regular_train_data, normed_train_data], axis=1, sort=False)

# regular_test_data = testData[["Year", "Visitor", "Home", "OT?"]]
normed_test_data = norm(testData.drop(["Year", "Visitor", "Home", "OT?"],axis=1))
# normed_test_data = pd.concat([regular_test_data, normed_test_data], axis=1, sort=False)

# %%
normed_train_data.head()
# Out:
#    FGA_PG_home  FGA_PG_visitor  FG%_PG_home  FG%_PG_visitor  3P_PG_home  \
# 0    -1.214672       -1.215684    -0.791002       -0.855600   -1.384283
# 1    -0.286871        0.696830     0.061838        0.196108   -0.859410
# 2    -0.511792       -0.540679    -1.250224        0.196108    0.146597
# 3    -0.314986       -2.087565    -0.594193       -1.578649   -1.690459
# 4    -0.314986       -0.681305    -0.134971       -0.395478   -1.602980
#
#    3P_PG_visitor  3PA_PG_home  3PA_PG_visitor  3P%_PG_home  3P%_PG_visitor  \
# 0      -0.377048    -1.359928       -0.429039    -0.636801        0.393050
# 1      -0.508487    -0.919317       -0.674166     0.388858        0.934153
# 2      -1.603811     0.157732       -1.572966    -0.096981       -0.905595
# 3      -0.420861    -1.653669       -0.314646    -1.338568       -0.689154
# 4      -1.559998    -1.621031       -1.605650    -0.420873       -0.310382
#
#    ...  TRB_PG_home  TRB_PG_visitor  AST_PG_home  AST_PG_visitor  STL_PG_home  \
# 0  ...     0.457665       -0.033353    -0.075489       -0.412745    -0.620329
# 1  ...     0.211872       -0.033353    -1.136529        1.231076     1.266296
# 2  ...     0.359348       -0.229994    -0.750697        0.940990    -1.563641
# 3  ...    -0.083079       -1.164035     0.310343       -1.814828     0.558812
# 4  ...     0.605140       -0.574114    -1.281217       -0.461093     0.205070
#
#    STL_PG_visitor  BLK_PG_home  BLK_PG_visitor  TOV_PG_home  TOV_PG_visitor
# 0       -0.737382     1.578872       -0.323159    -0.496750       -0.496735
# 1        0.794884     0.944254       -1.212264    -0.859138       -1.130925
# 2        1.855683    -0.832675        1.455049    -0.043765        0.499849
# 3       -0.030183     0.944254       -0.577189    -0.406153       -0.043742
# 4       -1.208849     0.690407       -1.720323     1.586982       -0.496735
#
# [5 rows x 28 columns]

# %%
# normed_train_data = norm(trainData)

# normed_test_data = norm(testData)

# %%
X = normed_train_data

y = normed_test_data.to_numpy()

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=[len(normed_train_data.keys())]),
    layers.Dense(128, activation='relu'),
    layers.Dense(1)
  ])

#   optimizer = tf.keras.optimizers.RMSprop(0.001)


  model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
  return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_39 (Dense)             (None, 128)               3712
# _________________________________________________________________
# dense_40 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 20,353
# Trainable params: 20,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_labels[:10]
# Out:
# 19463     True
# 19464     True
# 19465     True
# 19466    False
# 19467     True
# 19468    False
# 19469     True
# 19470     True
# 19471     True
# 19472     True
# Name: HomeWin, dtype: bool

# %%
example_batch = normed_train_data[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# array([[0.14726642],
#        [0.31989822],
#        [0.45014924],
#        [0.80416185],
#        [0.5290611 ],
#        [0.39065754],
#        [0.66236484],
#        [0.47655994],
#        [0.38468108],
#        [0.63187337]], dtype=float32)

# %%
EPOCHS = 700

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[tfdocs.modeling.EpochDots()])
# Out:
# Epoch: 0, accuracy:0.6267,  loss:0.7866,  val_accuracy:0.6211,  val_loss:1.8099,
# ....................................................................................................
# Epoch: 100, accuracy:0.7771,  loss:0.4450,  val_accuracy:0.6167,  val_loss:1.4526,
# ....................................................................................................
# Epoch: 200, accuracy:0.7987,  loss:0.4629,  val_accuracy:0.6080,  val_loss:2.5172,
# ....................................................................................................
# Epoch: 300, accuracy:0.8154,  loss:0.4315,  val_accuracy:0.6165,  val_loss:2.7961,
# ....................................................................................................
# Epoch: 400, accuracy:0.8254,  loss:0.4190,  val_accuracy:0.6273,  val_loss:2.4355,
# ....................................................................................................
# Epoch: 500, accuracy:0.8325,  loss:0.4007,  val_accuracy:0.6021,  val_loss:3.0580,
# ....................................................................................................
# Epoch: 600, accuracy:0.8284,  loss:0.3991,  val_accuracy:0.6242,  val_loss:3.1909,
# ....................................................................................................

# %%
# example_batch = normed_train_data[:10]
# example_result = model.predict(example_batch)
# example_result

# %%
# hist = pd.DataFrame(history.history)
# hist['epoch'] = history.epoch
# hist.tail()

# %%
# plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)

# %%
# plotter.plot({'Basic': history}, metric = "mae")
# plt.ylim([0, 10])
# plt.ylabel('MAE [Home Spread]')

# %%
# plotter.plot({'Basic': history}, metric = "mse")
# plt.ylim([0, 100])
# plt.ylabel('MSE [Spread^2]')

# %%
loss, accuracy = model.evaluate(normed_train_data, train_labels)
print("Train Accuracy:", accuracy)
# Out:
# 19463/19463 [==============================] - 0s 20us/sample - loss: 1.0512 - accuracy: 0.7956
# Train Accuracy: 0.7956122

# %%
loss, accuracy = model.evaluate(normed_test_data, test_labels)
print("Test Accuracy:", accuracy)
# Out:
# 971/971 [==============================] - 0s 27us/sample - loss: 4.5841 - accuracy: 0.5942
# Test Accuracy: 0.59423274

# %% [markdown]
# ### Model that stops based on improvement of MSE

# %%
model = build_model()

# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

early_history = model.fit(normed_train_data, train_labels, 
                    epochs=EPOCHS, validation_split = 0.2, verbose=0, 
                    callbacks=[early_stop, tfdocs.modeling.EpochDots()])
# Out:
# Epoch: 0, accuracy:0.6071,  loss:0.8775,  val_accuracy:0.6085,  val_loss:1.2932,
# ..............

# %%
loss, accuracy = model.evaluate(normed_train_data, train_labels)
print("Train Accuracy:", accuracy)
# Out:
# 19463/19463 [==============================] - 0s 20us/sample - loss: 0.6979 - accuracy: 0.6703
# Train Accuracy: 0.6702975

# %%
loss, accuracy = model.evaluate(normed_test_data, test_labels)
print("Test Accuracy:", accuracy)
# Out:
# 971/971 [==============================] - 0s 22us/sample - loss: 1.4039 - accuracy: 0.5839
# Test Accuracy: 0.58393407

# %%
test_predictions = model.predict(normed_test_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Home Spread]')
plt.ylabel('Predictions [Home Spread]')
lims = [0, 40]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
error = test_predictions - test_labels
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error [Home Spread]")
_ = plt.ylabel("Count")

# %%
# model = tf.keras.models.Sequential()
# model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
# model.add(keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
# model.add(keras.layers.Dropout(0.5))
# model.add(tf.keras.layers.Dense(1, activation=tf.nn.sigmoid))

# model.compile(optimizer='rmsprop',
#               loss='binary_crossentropy',
#               metrics=['accuracy'])

# model.fit(X_train, y_train, epochs=20)

# %%
# val_loss, val_acc = model.evaluate(X_test, y_test)
# print(val_loss, val_acc)
